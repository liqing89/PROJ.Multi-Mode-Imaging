# %% [markdown]
# #### 脚本说明
# 该脚本用于批量化生产仿真图像
# 批量化生产仿真图像的脚本构造如下：
# 1. 根据下视角及场景大小初始化pov文件头

# %%
import tqdm
import numpy as np
import subprocess
import os
import shutil
from txtProcess import * # 电磁建模结果处理文件
import scipy.io as sio # 后面三个为成像库
from read_data import * 
from Five_mode_imaging import *
import matplotlib.image as mpimg

# %%
# v-2023.8.24
#-------------------------------------------------------------------------------
# 步骤1参数
# 俯仰角设置
# incidentAngle = 73
# 场景大小：舰船-255*255、航母-505*505，坦克-35*35，飞机-95*95，地面大场景单独设置
distributionx = 95
distributiony = 95
model_name = 'C17'
#-------------------------------------------------------------------------------
# 步骤2参数
# 射线数量：舰船-600、航母-650，坦克-600，飞机-750，地面大场景单独设置
RayH = 750
RayW = 750
#-------------------------------------------------------------------------------
# 步骤3参数
target = 'FJ' # JC 舰船   TK 坦克   FJ 飞机   HM 航母
# 场景大小：舰船-250*250、航母-500*500，坦克-30*30，飞机-90*90，地面大场景单独设置
x_cut = 90
y_cut = 90
#-------------------------------------------------------------------------------
# 步骤4参数
# 分辨率：舰船、航母-1m，坦克-0.3m、飞机-0.3m，地面大场景单独设置
scanMode = 1         # 扫描模式
rngRho = 0.3        # 距离分辨
azmRho = 0.3        # 方位分辨
#-------------------------------------------------------------------------------
# 步骤5参数
# 凯撒窗系数：舰船、航母-1.5，坦克、飞机-4.7
beta = 4.7
#-------------------------------------------------------------------------------
# 设置存取初始POV文件夹
POV_folder = '/home/liq/pro/35POVs/'
# 设置运行文件夹
folder = '/home/liq/pro/35Targets/'
main_folder = folder + model_name

# %%
# 暂存变量，不用进行更改，方便程序运行
if os.path.exists(main_folder):
    shutil.rmtree(main_folder)
mk_save_main_floder = 'mkdir ' + model_name
result = subprocess.run(mk_save_main_floder, shell=True, capture_output=True, text=True, cwd=folder, check=True)

save_pov_folder_name = main_folder + '/pov/'
save_txt_folder_name = main_folder + '/txt/'
save_mat_folder_name =  main_folder + '/mat/'
save_echo_folder_name =  main_folder + '/echo/'
save_img_folder_name = main_folder + '/img/'
save_png_folder_name = main_folder + '/png/'

# %% [markdown]
# 步骤1：初始化多俯仰角、多方位角pov文件

# %%
print('开始生产目标：' + model_name + '，目标类型：' + target)
filename = POV_folder + model_name +'.pov'

if os.path.exists(save_pov_folder_name):
    shutil.rmtree(save_pov_folder_name)
mk_save_pov_floder = 'mkdir pov'
result = subprocess.run(mk_save_pov_floder, shell=True, capture_output=True, text=True, cwd=main_folder, check=True)

for incidentAngle in range(20,56,5):
    # 俯仰角设置

    # 根据下视角和方位角计算相机位置
    # 相机初始位置,即方位角为0时
    Z = 700*np.cos(incidentAngle/180 * np.pi)
    Y = 700*np.sin(incidentAngle/180 * np.pi)
    # 调整场景大小
    distributiony_change = np.sqrt((distributiony+1e6/np.cos(incidentAngle/180 * np.pi))**2-(1e6)**2)-1e6/np.cos(incidentAngle/180 * np.pi)*np.sin(incidentAngle/180 * np.pi)
    
    # 方位角设置
    for j in range(0,37,1):
        current_main_degree = j*10
        flag = 0
        # for i in range(current_main_degree*2-5,current_main_degree*2+6):
        for i in range(1):
            #当前角度
            current_degree = current_main_degree
            Z0 = Z
            Y0 = Y*np.cos(current_degree/180 * np.pi)
            X0 = Y*np.sin(current_degree/180 * np.pi)*(-1)

            content = ['#include "colors.inc"\n#include "finish.inc"\nglobal_settings{SAR_Output_Data 1 SAR_Intersection 1}\n']
            camera = ['#declare Cam = camera {\northographic\n']
            cameraPos = 'location <' + str(X0) + ',' + str(Z0) + ',' + str(Y0) + '>' + '\n'
            camera.append(cameraPos)
            camera.append('look_at < 0 , 0 , 0 >\n')

            camera.append('right ' + str(distributionx) + '*x\n')
            camera.append('up ' + str(distributiony_change) + '*y\n')
            camera.append('}\n')
            content = content + camera

            content.append('camera{Cam}\n')

            content.append('light_source {\n0*x\ncolor rgb <1,1,1>\nparallel\ntranslate <'+str(X0)+','+str(Z0)+','+str(Y0)+'>\npoint_at < 0 , 0 , 0 >\n}\n')

            content.append('plane {\n<0,1,0>\n0\ntexture {\npigment { color rgb<1, 1, 1> }\nfinish {reflection {0.2} ambient 0 diffuse 0.001 specular 0.5 roughness 0.0033}\n}\n}\n')

            with open(filename,'r',encoding='utf-8') as f1:
                lines = []
                for line in f1.readlines():
                    lines += [line]
            f1.close()

            content = content + lines

            savefilename = save_pov_folder_name+str(incidentAngle)+'_'+str(current_main_degree)+'_'+ str(flag) +'.pov'

            with open(savefilename,'w',encoding='utf-8') as f:
                f.writelines(content)
            f.close()
            flag += 1
        print('已完成俯仰角 {} 度, 方位角 {} 度的pov文件初始化。'.format(incidentAngle, 10*j))
# Out:
# 开始生产目标：C17，目标类型：FJ
# 已完成俯仰角 20 度, 方位角 0 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 10 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 20 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 30 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 40 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 50 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 60 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 70 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 80 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 90 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 100 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 110 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 120 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 130 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 140 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 150 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 160 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 170 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 180 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 190 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 200 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 210 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 220 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 230 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 240 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 250 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 260 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 270 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 280 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 290 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 300 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 310 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 320 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 330 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 340 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 350 度的pov文件初始化。
# 已完成俯仰角 20 度, 方位角 360 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 0 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 10 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 20 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 30 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 40 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 50 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 60 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 70 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 80 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 90 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 100 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 110 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 120 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 130 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 140 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 150 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 160 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 170 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 180 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 190 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 200 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 210 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 220 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 230 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 240 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 250 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 260 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 270 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 280 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 290 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 300 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 310 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 320 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 330 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 340 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 350 度的pov文件初始化。
# 已完成俯仰角 25 度, 方位角 360 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 0 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 10 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 20 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 30 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 40 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 50 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 60 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 70 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 80 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 90 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 100 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 110 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 120 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 130 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 140 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 150 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 160 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 170 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 180 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 190 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 200 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 210 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 220 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 230 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 240 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 250 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 260 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 270 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 280 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 290 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 300 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 310 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 320 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 330 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 340 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 350 度的pov文件初始化。
# 已完成俯仰角 30 度, 方位角 360 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 0 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 10 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 20 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 30 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 40 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 50 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 60 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 70 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 80 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 90 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 100 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 110 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 120 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 130 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 140 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 150 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 160 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 170 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 180 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 190 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 200 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 210 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 220 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 230 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 240 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 250 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 260 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 270 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 280 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 290 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 300 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 310 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 320 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 330 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 340 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 350 度的pov文件初始化。
# 已完成俯仰角 35 度, 方位角 360 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 0 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 10 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 20 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 30 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 40 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 50 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 60 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 70 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 80 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 90 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 100 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 110 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 120 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 130 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 140 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 150 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 160 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 170 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 180 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 190 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 200 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 210 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 220 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 230 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 240 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 250 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 260 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 270 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 280 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 290 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 300 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 310 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 320 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 330 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 340 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 350 度的pov文件初始化。
# 已完成俯仰角 40 度, 方位角 360 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 0 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 10 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 20 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 30 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 40 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 50 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 60 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 70 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 80 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 90 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 100 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 110 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 120 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 130 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 140 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 150 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 160 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 170 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 180 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 190 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 200 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 210 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 220 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 230 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 240 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 250 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 260 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 270 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 280 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 290 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 300 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 310 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 320 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 330 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 340 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 350 度的pov文件初始化。
# 已完成俯仰角 45 度, 方位角 360 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 0 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 10 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 20 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 30 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 40 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 50 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 60 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 70 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 80 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 90 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 100 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 110 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 120 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 130 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 140 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 150 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 160 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 170 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 180 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 190 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 200 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 210 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 220 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 230 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 240 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 250 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 260 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 270 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 280 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 290 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 300 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 310 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 320 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 330 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 340 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 350 度的pov文件初始化。
# 已完成俯仰角 50 度, 方位角 360 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 0 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 10 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 20 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 30 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 40 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 50 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 60 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 70 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 80 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 90 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 100 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 110 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 120 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 130 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 140 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 150 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 160 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 170 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 180 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 190 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 200 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 210 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 220 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 230 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 240 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 250 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 260 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 270 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 280 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 290 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 300 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 310 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 320 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 330 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 340 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 350 度的pov文件初始化。
# 已完成俯仰角 55 度, 方位角 360 度的pov文件初始化。

# %% [markdown]
# 步骤2：对pov文件进行电磁建模

# %%
if os.path.exists(save_txt_folder_name):
    shutil.rmtree(save_txt_folder_name)
mk_save_txt_floder = 'mkdir txt'
result = subprocess.run(mk_save_txt_floder, shell=True, capture_output=True, text=True, cwd=main_folder, check=True)

for k in range(20,56,5):
    for i in range(0,37,1):
        main_degree = 10*i
        current_name_prefix = save_pov_folder_name+str(k)+'_'+str(main_degree)
        for j in range(1):
            current_file_name = current_name_prefix + '_' + str(j) + '.pov'

            runCommand = 'povray '+ current_file_name +' -D +W'+str(RayW)+' +H'+str(RayH)
            result = subprocess.run(runCommand, shell=True, capture_output=True, text=True, cwd=save_txt_folder_name, check=True)

            reviseFilenameCommand = 'mv Contributions.txt Contributions_'+str(k)+'_'+str(main_degree) + '_' + str(j) + '.txt'
            result = subprocess.run(reviseFilenameCommand, shell=True, capture_output=True, text=True, cwd=save_txt_folder_name, check=True)
        print('已完成俯仰角 {} 度, 方位角 {} 度的电磁建模。'.format(k, 10*i))
# Out:
# 已完成俯仰角 20 度, 方位角 0 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 10 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 20 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 30 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 40 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 50 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 60 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 70 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 80 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 90 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 100 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 110 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 120 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 130 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 140 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 150 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 160 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 170 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 180 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 190 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 200 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 210 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 220 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 230 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 240 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 250 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 260 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 270 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 280 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 290 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 300 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 310 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 320 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 330 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 340 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 350 度的电磁建模。
# 已完成俯仰角 20 度, 方位角 360 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 0 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 10 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 20 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 30 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 40 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 50 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 60 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 70 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 80 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 90 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 100 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 110 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 120 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 130 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 140 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 150 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 160 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 170 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 180 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 190 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 200 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 210 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 220 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 230 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 240 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 250 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 260 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 270 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 280 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 290 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 300 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 310 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 320 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 330 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 340 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 350 度的电磁建模。
# 已完成俯仰角 25 度, 方位角 360 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 0 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 10 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 20 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 30 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 40 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 50 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 60 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 70 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 80 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 90 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 100 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 110 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 120 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 130 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 140 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 150 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 160 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 170 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 180 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 190 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 200 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 210 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 220 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 230 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 240 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 250 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 260 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 270 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 280 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 290 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 300 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 310 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 320 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 330 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 340 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 350 度的电磁建模。
# 已完成俯仰角 30 度, 方位角 360 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 0 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 10 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 20 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 30 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 40 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 50 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 60 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 70 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 80 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 90 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 100 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 110 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 120 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 130 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 140 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 150 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 160 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 170 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 180 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 190 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 200 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 210 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 220 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 230 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 240 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 250 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 260 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 270 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 280 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 290 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 300 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 310 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 320 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 330 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 340 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 350 度的电磁建模。
# 已完成俯仰角 35 度, 方位角 360 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 0 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 10 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 20 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 30 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 40 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 50 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 60 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 70 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 80 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 90 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 100 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 110 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 120 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 130 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 140 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 150 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 160 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 170 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 180 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 190 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 200 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 210 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 220 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 230 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 240 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 250 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 260 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 270 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 280 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 290 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 300 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 310 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 320 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 330 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 340 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 350 度的电磁建模。
# 已完成俯仰角 40 度, 方位角 360 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 0 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 10 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 20 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 30 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 40 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 50 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 60 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 70 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 80 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 90 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 100 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 110 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 120 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 130 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 140 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 150 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 160 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 170 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 180 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 190 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 200 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 210 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 220 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 230 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 240 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 250 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 260 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 270 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 280 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 290 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 300 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 310 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 320 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 330 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 340 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 350 度的电磁建模。
# 已完成俯仰角 45 度, 方位角 360 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 0 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 10 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 20 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 30 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 40 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 50 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 60 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 70 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 80 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 90 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 100 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 110 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 120 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 130 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 140 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 150 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 160 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 170 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 180 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 190 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 200 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 210 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 220 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 230 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 240 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 250 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 260 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 270 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 280 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 290 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 300 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 310 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 320 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 330 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 340 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 350 度的电磁建模。
# 已完成俯仰角 50 度, 方位角 360 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 0 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 10 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 20 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 30 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 40 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 50 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 60 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 70 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 80 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 90 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 100 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 110 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 120 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 130 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 140 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 150 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 160 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 170 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 180 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 190 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 200 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 210 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 220 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 230 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 240 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 250 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 260 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 270 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 280 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 290 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 300 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 310 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 320 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 330 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 340 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 350 度的电磁建模。
# 已完成俯仰角 55 度, 方位角 360 度的电磁建模。

# %% [markdown]
# 步骤3：对建模结果进行裁剪处理

# %%
if os.path.exists(save_mat_folder_name):
    shutil.rmtree(save_mat_folder_name)
mk_save_mat_floder = 'mkdir mat'
result = subprocess.run(mk_save_mat_floder, shell=True, capture_output=True, text=True, cwd=main_folder, check=True)

for k in range(20,56,5):
    x_cut_change = np.sqrt((x_cut+1e6/np.cos(k/180 * np.pi))**2-(1e6)**2)-1e6/np.cos(k/180 * np.pi)*np.sin(k/180 * np.pi)
    for i in range(0,37,1):
        main_degree = 10*i
        current_name_prefix = save_txt_folder_name + 'Contributions_' + str(k) + '_' + str(main_degree)
        for j in range(1):
            current_file_name = current_name_prefix + '_' + str(j) + '.txt'
            txtProParams = [main_degree,k, 0, target, 'HH', x_cut_change, y_cut, current_file_name]
            elecResult = txtProcess(txtProParams)
            savedic = {"data": elecResult, "offNadiAng": k}
            resultMatFile = "{}mat_{}_{}_{}.mat".format(save_mat_folder_name, k, main_degree, j)
            sio.savemat(resultMatFile, savedic)
        print('已完成俯仰角 {} 度, 方位角 {} 度的电磁建模裁剪工作。'.format(k, 10*i))
# Out:
# 0.263854 8.6e-05
# 0.199591 1e-06
# 已完成俯仰角 20 度, 方位角 0 度的电磁建模裁剪工作。
# 0.328339 1.8e-05
# 0.037796 2e-06
# 已完成俯仰角 20 度, 方位角 10 度的电磁建模裁剪工作。
# 0.285574 1.2e-05
# 0.067777 1e-06
# 已完成俯仰角 20 度, 方位角 20 度的电磁建模裁剪工作。
# 0.21946 1.8e-05
# 0.105887 1e-06
# 已完成俯仰角 20 度, 方位角 30 度的电磁建模裁剪工作。
# 0.635965 2.4e-05
# 0.059011 1e-06
# 已完成俯仰角 20 度, 方位角 40 度的电磁建模裁剪工作。
# 0.421233 1.4e-05
# 0.100207 1e-06
# 已完成俯仰角 20 度, 方位角 50 度的电磁建模裁剪工作。
# 0.508859 6.5e-05
# 0.067835 1e-06
# 已完成俯仰角 20 度, 方位角 60 度的电磁建模裁剪工作。
# 0.511544 7.1e-05
# 0.096316 2e-06
# 已完成俯仰角 20 度, 方位角 70 度的电磁建模裁剪工作。
# 0.59126 1.3e-05
# 0.130352 3e-06
# 已完成俯仰角 20 度, 方位角 80 度的电磁建模裁剪工作。
# 0.4079 1.9e-05
# 0.150282 4e-06
# 已完成俯仰角 20 度, 方位角 90 度的电磁建模裁剪工作。
# 0.104205 3.1e-05
# 0.193406 5e-06
# 已完成俯仰角 20 度, 方位角 100 度的电磁建模裁剪工作。
# 0.400694 2.2e-05
# 0.107963 1e-06
# 已完成俯仰角 20 度, 方位角 110 度的电磁建模裁剪工作。
# 0.427602 3.2e-05
# 0.201472 9e-06
# 已完成俯仰角 20 度, 方位角 120 度的电磁建模裁剪工作。
# 0.379382 3.1e-05
# 0.014842 1e-06
# 已完成俯仰角 20 度, 方位角 130 度的电磁建模裁剪工作。
# 0.446942 2.5e-05
# 0.079334 3e-06
# 已完成俯仰角 20 度, 方位角 140 度的电磁建模裁剪工作。
# 0.576535 1.7e-05
# 0.003377 1e-06
# 已完成俯仰角 20 度, 方位角 150 度的电磁建模裁剪工作。
# 0.033371 1e-05
# 0.063488 4e-06
# 已完成俯仰角 20 度, 方位角 160 度的电磁建模裁剪工作。
# 0.37726 2.4e-05
# 0.0262 8e-06
# 已完成俯仰角 20 度, 方位角 170 度的电磁建模裁剪工作。
# 0.530854 5.9e-05
# 0.002549 3e-06
# 已完成俯仰角 20 度, 方位角 180 度的电磁建模裁剪工作。
# 0.256941 1.2e-05
# 0.082272 6e-06
# 已完成俯仰角 20 度, 方位角 190 度的电磁建模裁剪工作。
# 0.028003 1.8e-05
# 0.008679 1e-06
# 已完成俯仰角 20 度, 方位角 200 度的电磁建模裁剪工作。
# 0.38075 3e-06
# 0.007967 1e-06
# 已完成俯仰角 20 度, 方位角 210 度的电磁建模裁剪工作。
# 0.136512 4.6e-05
# 0.074589 4e-06
# 已完成俯仰角 20 度, 方位角 220 度的电磁建模裁剪工作。
# 0.379382 7.8e-05
# 0.019095 2e-06
# 已完成俯仰角 20 度, 方位角 230 度的电磁建模裁剪工作。
# 0.610393 2.1e-05
# 0.127578 8e-06
# 已完成俯仰角 20 度, 方位角 240 度的电磁建模裁剪工作。
# 0.400701 6.1e-05
# 0.074143 1e-06
# 已完成俯仰角 20 度, 方位角 250 度的电磁建模裁剪工作。
# 0.104202 4.3e-05
# 0.176135 5e-06
# 已完成俯仰角 20 度, 方位角 260 度的电磁建模裁剪工作。
# 0.407922 3e-05
# 0.150282 4e-06
# 已完成俯仰角 20 度, 方位角 270 度的电磁建模裁剪工作。
# 0.591255 1.7e-05
# 0.082272 2e-06
# 已完成俯仰角 20 度, 方位角 280 度的电磁建模裁剪工作。
# 0.511531 5.4e-05
# 0.12936 2e-06
# 已完成俯仰角 20 度, 方位角 290 度的电磁建模裁剪工作。
# 0.508856 7.1e-05
# 0.147118 1e-06
# 已完成俯仰角 20 度, 方位角 300 度的电磁建模裁剪工作。
# 0.421238 5.6e-05
# 0.100211 1e-06
# 已完成俯仰角 20 度, 方位角 310 度的电磁建模裁剪工作。
# 0.635954 6.5e-05
# 0.097237 1e-06
# 已完成俯仰角 20 度, 方位角 320 度的电磁建模裁剪工作。
# 0.219499 2.3e-05
# 0.069747 1e-06
# 已完成俯仰角 20 度, 方位角 330 度的电磁建模裁剪工作。
# 0.635935 1.1e-05
# 0.067777 1e-06
# 已完成俯仰角 20 度, 方位角 340 度的电磁建模裁剪工作。
# 0.328339 9e-06
# 0.107256 3e-06
# 已完成俯仰角 20 度, 方位角 350 度的电磁建模裁剪工作。
# 0.263854 8.6e-05
# 0.199591 1e-06
# 已完成俯仰角 20 度, 方位角 360 度的电磁建模裁剪工作。
# 0.196815 5.6e-05
# 0.061539 3e-06
# 已完成俯仰角 25 度, 方位角 0 度的电磁建模裁剪工作。
# 0.386172 2.6e-05
# 0.1016 1e-06
# 已完成俯仰角 25 度, 方位角 10 度的电磁建模裁剪工作。
# 0.668269 3.7e-05
# 0.049039 2e-06
# 已完成俯仰角 25 度, 方位角 20 度的电磁建模裁剪工作。
# 0.284513 5.4e-05
# 0.11334 2e-06
# 已完成俯仰角 25 度, 方位角 30 度的电磁建模裁剪工作。
# 0.448435 5.4e-05
# 0.073605 1e-06
# 已完成俯仰角 25 度, 方位角 40 度的电磁建模裁剪工作。
# 0.238401 4e-05
# 0.109849 1e-06
# 已完成俯仰角 25 度, 方位角 50 度的电磁建模裁剪工作。
# 0.192647 2.4e-05
# 0.040858 1e-06
# 已完成俯仰角 25 度, 方位角 60 度的电磁建模裁剪工作。
# 0.498612 2.4e-05
# 0.198524 3e-06
# 已完成俯仰角 25 度, 方位角 70 度的电磁建模裁剪工作。
# 0.568342 2e-05
# 0.097447 9e-06
# 已完成俯仰角 25 度, 方位角 80 度的电磁建模裁剪工作。
# 0.209104 8.2e-05
# 0.150272 5e-06
# 已完成俯仰角 25 度, 方位角 90 度的电磁建模裁剪工作。
# 0.219706 3.5e-05
# 0.209378 1e-06
# 已完成俯仰角 25 度, 方位角 100 度的电磁建模裁剪工作。
# 0.515758 3.7e-05
# 0.103347 1e-06
# 已完成俯仰角 25 度, 方位角 110 度的电磁建模裁剪工作。
# 0.686047 4.3e-05
# 0.073346 3e-06
# 已完成俯仰角 25 度, 方位角 120 度的电磁建模裁剪工作。
# 0.498274 6.5e-05
# 0.00409 1e-06
# 已完成俯仰角 25 度, 方位角 130 度的电磁建模裁剪工作。
# 0.262173 1.6e-05
# 0.144968 1e-06
# 已完成俯仰角 25 度, 方位角 140 度的电磁建模裁剪工作。
# 0.366601 1.4e-05
# 0.064612 3e-06
# 已完成俯仰角 25 度, 方位角 150 度的电磁建模裁剪工作。
# 0.085601 3.3e-05
# 0.008173 1e-06
# 已完成俯仰角 25 度, 方位角 160 度的电磁建模裁剪工作。
# 0.509904 5.4e-05
# 0.006978 1e-06
# 已完成俯仰角 25 度, 方位角 170 度的电磁建模裁剪工作。
# 0.007877 1.2e-05
# 0.150272 3e-06
# 已完成俯仰角 25 度, 方位角 180 度的电磁建模裁剪工作。
# 0.50988 4e-05
# 0.139352 1e-06
# 已完成俯仰角 25 度, 方位角 190 度的电磁建模裁剪工作。
# 0.08561 2.8e-05
# 0.008174 1e-06
# 已完成俯仰角 25 度, 方位角 200 度的电磁建模裁剪工作。
# 0.356803 2.7e-05
# 0.0653 3e-06
# 已完成俯仰角 25 度, 方位角 210 度的电磁建模裁剪工作。
# 0.336423 1.5e-05
# 0.058541 1e-06
# 已完成俯仰角 25 度, 方位角 220 度的电磁建模裁剪工作。
# 0.498272 2.7e-05
# 0.005796 1e-06
# 已完成俯仰角 25 度, 方位角 230 度的电磁建模裁剪工作。
# 0.686073 4.3e-05
# 0.092205 3e-06
# 已完成俯仰角 25 度, 方位角 240 度的电磁建模裁剪工作。
# 0.515734 3.2e-05
# 0.14495 1e-06
# 已完成俯仰角 25 度, 方位角 250 度的电磁建模裁剪工作。
# 0.219696 7e-06
# 0.204549 1e-06
# 已完成俯仰角 25 度, 方位角 260 度的电磁建模裁剪工作。
# 0.209094 5.4e-05
# 0.150272 5e-06
# 已完成俯仰角 25 度, 方位角 270 度的电磁建模裁剪工作。
# 0.568357 2.1e-05
# 0.097441 6e-06
# 已完成俯仰角 25 度, 方位角 280 度的电磁建模裁剪工作。
# 0.498596 5.7e-05
# 0.20698 3e-06
# 已完成俯仰角 25 度, 方位角 290 度的电磁建模裁剪工作。
# 0.15226 1.6e-05
# 0.046471 1e-06
# 已完成俯仰角 25 度, 方位角 300 度的电磁建模裁剪工作。
# 0.394778 4e-05
# 0.146859 6e-06
# 已完成俯仰角 25 度, 方位角 310 度的电磁建模裁剪工作。
# 0.448435 3e-06
# 0.080879 1e-06
# 已完成俯仰角 25 度, 方位角 320 度的电磁建模裁剪工作。
# 0.284435 1.8e-05
# 0.113339 2e-06
# 已完成俯仰角 25 度, 方位角 330 度的电磁建模裁剪工作。
# 0.668251 3.1e-05
# 0.049039 2e-06
# 已完成俯仰角 25 度, 方位角 340 度的电磁建模裁剪工作。
# 0.216505 2.6e-05
# 0.101597 1e-06
# 已完成俯仰角 25 度, 方位角 350 度的电磁建模裁剪工作。
# 0.196815 5.6e-05
# 0.061539 3e-06
# 已完成俯仰角 25 度, 方位角 360 度的电磁建模裁剪工作。
# 0.02796 1.4e-05
# 0.109444 3e-06
# 已完成俯仰角 30 度, 方位角 0 度的电磁建模裁剪工作。
# 0.431446 8e-06
# 0.058334 2e-06
# 已完成俯仰角 30 度, 方位角 10 度的电磁建模裁剪工作。
# 0.098515 1.7e-05
# 0.164972 1e-06
# 已完成俯仰角 30 度, 方位角 20 度的电磁建模裁剪工作。
# 0.005472 8e-06
# 0.113124 1e-06
# 已完成俯仰角 30 度, 方位角 30 度的电磁建模裁剪工作。
# 0.023168 4.8e-05
# 0.077722 5e-06
# 已完成俯仰角 30 度, 方位角 40 度的电磁建模裁剪工作。
# 0.219545 3e-05
# 0.145058 1e-06
# 已完成俯仰角 30 度, 方位角 50 度的电磁建模裁剪工作。
# 0.666211 1.1e-05
# 0.155006 1e-06
# 已完成俯仰角 30 度, 方位角 60 度的电磁建模裁剪工作。
# 0.218971 6.9e-05
# 0.128222 4e-06
# 已完成俯仰角 30 度, 方位角 70 度的电磁建模裁剪工作。
# 0.098189 1.8e-05
# 0.145118 2e-06
# 已完成俯仰角 30 度, 方位角 80 度的电磁建模裁剪工作。
# 0.284705 6.1e-05
# 0.204901 1e-06
# 已完成俯仰角 30 度, 方位角 90 度的电磁建模裁剪工作。
# 0.370484 1.1e-05
# 0.201383 1e-06
# 已完成俯仰角 30 度, 方位角 100 度的电磁建模裁剪工作。
# 0.648692 2.3e-05
# 0.194732 2e-06
# 已完成俯仰角 30 度, 方位角 110 度的电磁建模裁剪工作。
# 0.338817 1e-05
# 0.01727 1e-06
# 已完成俯仰角 30 度, 方位角 120 度的电磁建模裁剪工作。
# 0.329887 1.1e-05
# 0.144462 1e-06
# 已完成俯仰角 30 度, 方位角 130 度的电磁建模裁剪工作。
# 0.295554 3.1e-05
# 0.141836 1e-06
# 已完成俯仰角 30 度, 方位角 140 度的电磁建模裁剪工作。
# 0.170707 2.2e-05
# 0.126813 2e-06
# 已完成俯仰角 30 度, 方位角 150 度的电磁建模裁剪工作。
# 0.009453 3.3e-05
# 0.007649 1e-06
# 已完成俯仰角 30 度, 方位角 160 度的电磁建模裁剪工作。
# 0.002593 3.4e-05
# 0.133845 2e-06
# 已完成俯仰角 30 度, 方位角 170 度的电磁建模裁剪工作。
# 0.002008 3.1e-05
# 0.15026 3e-06
# 已完成俯仰角 30 度, 方位角 180 度的电磁建模裁剪工作。
# 0.002593 2.7e-05
# 0.133846 2e-06
# 已完成俯仰角 30 度, 方位角 190 度的电磁建模裁剪工作。
# 0.009454 3.9e-05
# 0.01335 1e-06
# 已完成俯仰角 30 度, 方位角 200 度的电磁建模裁剪工作。
# 0.170715 2.6e-05
# 0.124504 2e-06
# 已完成俯仰角 30 度, 方位角 210 度的电磁建模裁剪工作。
# 0.295563 1.5e-05
# 0.027555 1e-06
# 已完成俯仰角 30 度, 方位角 220 度的电磁建模裁剪工作。
# 0.329887 1.1e-05
# 0.001226 1e-06
# 已完成俯仰角 30 度, 方位角 230 度的电磁建模裁剪工作。
# 0.261339 0.000101
# 0.015946 2e-06
# 已完成俯仰角 30 度, 方位角 240 度的电磁建模裁剪工作。
# 0.648686 2.3e-05
# 0.202978 3e-06
# 已完成俯仰角 30 度, 方位角 250 度的电磁建模裁剪工作。
# 0.370485 2.9e-05
# 0.202432 1e-06
# 已完成俯仰角 30 度, 方位角 260 度的电磁建模裁剪工作。
# 0.284701 6e-05
# 0.205048 1e-06
# 已完成俯仰角 30 度, 方位角 270 度的电磁建模裁剪工作。
# 0.098188 2.5e-05
# 0.033655 2e-06
# 已完成俯仰角 30 度, 方位角 280 度的电磁建模裁剪工作。
# 0.218981 6.9e-05
# 0.128716 1e-06
# 已完成俯仰角 30 度, 方位角 290 度的电磁建模裁剪工作。
# 0.666211 1.1e-05
# 0.155627 1e-06
# 已完成俯仰角 30 度, 方位角 300 度的电磁建模裁剪工作。
# 0.219545 3.8e-05
# 0.093012 1e-06
# 已完成俯仰角 30 度, 方位角 310 度的电磁建模裁剪工作。
# 0.107795 4.8e-05
# 0.142841 5e-06
# 已完成俯仰角 30 度, 方位角 320 度的电磁建模裁剪工作。
# 0.003825 2e-05
# 0.113123 1e-06
# 已完成俯仰角 30 度, 方位角 330 度的电磁建模裁剪工作。
# 0.098509 2.1e-05
# 0.159095 1e-06
# 已完成俯仰角 30 度, 方位角 340 度的电磁建模裁剪工作。
# 0.132768 8e-06
# 0.079495 1e-06
# 已完成俯仰角 30 度, 方位角 350 度的电磁建模裁剪工作。
# 0.02796 1.4e-05
# 0.109444 3e-06
# 已完成俯仰角 30 度, 方位角 360 度的电磁建模裁剪工作。
# 0.00198 4.3e-05
# 0.14805 1e-06
# 已完成俯仰角 35 度, 方位角 0 度的电磁建模裁剪工作。
# 0.030624 2.1e-05
# 0.126031 1e-06
# 已完成俯仰角 35 度, 方位角 10 度的电磁建模裁剪工作。
# 0.0159 8e-06
# 0.030989 1e-06
# 已完成俯仰角 35 度, 方位角 20 度的电磁建模裁剪工作。
# 0.194465 6e-05
# 0.112839 3e-06
# 已完成俯仰角 35 度, 方位角 30 度的电磁建模裁剪工作。
# 0.3752 2.7e-05
# 0.13946 5e-06
# 已完成俯仰角 35 度, 方位角 40 度的电磁建模裁剪工作。
# 0.411861 2.9e-05
# 0.142661 1e-06
# 已完成俯仰角 35 度, 方位角 50 度的电磁建模裁剪工作。
# 0.165051 0.000106
# 0.034859 5e-06
# 已完成俯仰角 35 度, 方位角 60 度的电磁建模裁剪工作。
# 0.670495 8e-06
# 0.141087 1e-06
# 已完成俯仰角 35 度, 方位角 70 度的电磁建模裁剪工作。
# 0.499638 3.4e-05
# 0.114887 1e-06
# 已完成俯仰角 35 度, 方位角 80 度的电磁建模裁剪工作。
# 0.499906 2.9e-05
# 0.150246 7e-06
# 已完成俯仰角 35 度, 方位角 90 度的电磁建模裁剪工作。
# 0.533809 3.4e-05
# 0.179772 3e-06
# 已完成俯仰角 35 度, 方位角 100 度的电磁建模裁剪工作。
# 0.690973 4.5e-05
# 0.201175 1e-06
# 已完成俯仰角 35 度, 方位角 110 度的电磁建模裁剪工作。
# 0.508138 2.9e-05
# 0.025685 4e-06
# 已完成俯仰角 35 度, 方位角 120 度的电磁建模裁剪工作。
# 0.484143 3.1e-05
# 0.000599 2e-06
# 已完成俯仰角 35 度, 方位角 130 度的电磁建模裁剪工作。
# 0.142463 3.5e-05
# 0.022596 1e-06
# 已完成俯仰角 35 度, 方位角 140 度的电磁建模裁剪工作。
# 0.002827 3.9e-05
# 0.126186 2e-06
# 已完成俯仰角 35 度, 方位角 150 度的电磁建模裁剪工作。
# 0.001975 5.3e-05
# 0.010257 2e-06
# 已完成俯仰角 35 度, 方位角 160 度的电磁建模裁剪工作。
# 0.4188 1.8e-05
# 0.004932 5e-06
# 已完成俯仰角 35 度, 方位角 170 度的电磁建模裁剪工作。
# 0.001982 4e-06
# 0.148724 8e-06
# 已完成俯仰角 35 度, 方位角 180 度的电磁建模裁剪工作。
# 0.001972 2.8e-05
# 0.018914 1e-06
# 已完成俯仰角 35 度, 方位角 190 度的电磁建模裁剪工作。
# 0.002004 3.9e-05
# 0.006988 2e-06
# 已完成俯仰角 35 度, 方位角 200 度的电磁建模裁剪工作。
# 0.00197 3.9e-05
# 0.126187 3e-06
# 已完成俯仰角 35 度, 方位角 210 度的电磁建模裁剪工作。
# 0.002005 2e-05
# 0.024088 1e-06
# 已完成俯仰角 35 度, 方位角 220 度的电磁建模裁剪工作。
# 0.069591 3.3e-05
# 0.003737 2e-06
# 已完成俯仰角 35 度, 方位角 230 度的电磁建模裁剪工作。
# 0.508138 5.6e-05
# 0.015343 1e-06
# 已完成俯仰角 35 度, 方位角 240 度的电磁建模裁剪工作。
# 0.69096 3.2e-05
# 0.210375 1e-06
# 已完成俯仰角 35 度, 方位角 250 度的电磁建模裁剪工作。
# 0.533803 3.7e-05
# 0.181663 3e-06
# 已完成俯仰角 35 度, 方位角 260 度的电磁建模裁剪工作。
# 0.499897 4.7e-05
# 0.150246 9e-06
# 已完成俯仰角 35 度, 方位角 270 度的电磁建模裁剪工作。
# 0.499607 3.7e-05
# 0.099269 5e-06
# 已完成俯仰角 35 度, 方位角 280 度的电磁建模裁剪工作。
# 0.670503 5.4e-05
# 0.141088 1e-06
# 已完成俯仰角 35 度, 方位角 290 度的电磁建模裁剪工作。
# 0.258383 2.5e-05
# 0.075167 2e-06
# 已完成俯仰角 35 度, 方位角 300 度的电磁建模裁剪工作。
# 0.41164 6.3e-05
# 0.142661 1e-06
# 已完成俯仰角 35 度, 方位角 310 度的电磁建模裁剪工作。
# 0.375219 2.7e-05
# 0.139463 5e-06
# 已完成俯仰角 35 度, 方位角 320 度的电磁建模裁剪工作。
# 0.194527 2.3e-05
# 0.112838 3e-06
# 已完成俯仰角 35 度, 方位角 330 度的电磁建模裁剪工作。
# 0.0159 8e-06
# 0.017887 1e-06
# 已完成俯仰角 35 度, 方位角 340 度的电磁建模裁剪工作。
# 0.030624 1.1e-05
# 0.126026 2e-06
# 已完成俯仰角 35 度, 方位角 350 度的电磁建模裁剪工作。
# 0.00198 4.3e-05
# 0.14805 1e-06
# 已完成俯仰角 35 度, 方位角 360 度的电磁建模裁剪工作。
# 0.002068 5.7e-05
# 0.1327 2e-06
# 已完成俯仰角 40 度, 方位角 0 度的电磁建模裁剪工作。
# 0.104424 1.4e-05
# 0.068163 1e-06
# 已完成俯仰角 40 度, 方位角 10 度的电磁建模裁剪工作。
# 0.166831 1.5e-05
# 0.020243 1e-06
# 已完成俯仰角 40 度, 方位角 20 度的电磁建模裁剪工作。
# 0.685935 1.8e-05
# 0.112461 1e-06
# 已完成俯仰角 40 度, 方位角 30 度的电磁建模裁剪工作。
# 0.41137 3.2e-05
# 0.053734 1e-06
# 已完成俯仰角 40 度, 方位角 40 度的电磁建模裁剪工作。
# 0.333969 4.5e-05
# 0.139455 4e-06
# 已完成俯仰角 40 度, 方位角 50 度的电磁建模裁剪工作。
# 0.399228 4.2e-05
# 0.032439 1e-06
# 已完成俯仰角 40 度, 方位角 60 度的电磁建模裁剪工作。
# 0.65929 4.6e-05
# 0.140996 3e-06
# 已完成俯仰角 40 度, 方位角 70 度的电磁建模裁剪工作。
# 0.572355 1.8e-05
# 0.144729 1e-06
# 已完成俯仰角 40 度, 方位角 80 度的电磁建模裁剪工作。
# 0.267401 4.2e-05
# 0.15023 1e-06
# 已完成俯仰角 40 度, 方位角 90 度的电磁建模裁剪工作。
# 0.696842 4.4e-05
# 0.141573 4e-06
# 已完成俯仰角 40 度, 方位角 100 度的电磁建模裁剪工作。
# 0.635338 8e-06
# 0.187984 2e-06
# 已完成俯仰角 40 度, 方位角 110 度的电磁建模裁剪工作。
# 0.4129 4.3e-05
# 0.003966 1e-06
# 已完成俯仰角 40 度, 方位角 120 度的电磁建模裁剪工作。
# 0.035069 4.1e-05
# 0.000598 5e-06
# 已完成俯仰角 40 度, 方位角 130 度的电磁建模裁剪工作。
# 0.002068 1.5e-05
# 0.010953 1e-06
# 已完成俯仰角 40 度, 方位角 140 度的电磁建模裁剪工作。
# 0.001964 1.3e-05
# 0.124746 2e-06
# 已完成俯仰角 40 度, 方位角 150 度的电磁建模裁剪工作。
# 0.002177 2.1e-05
# 0.006201 2e-06
# 已完成俯仰角 40 度, 方位角 160 度的电磁建模裁剪工作。
# 0.001984 1.7e-05
# 0.008411 1e-06
# 已完成俯仰角 40 度, 方位角 170 度的电磁建模裁剪工作。
# 0.001977 1.2e-05
# 0.148597 3e-06
# 已完成俯仰角 40 度, 方位角 180 度的电磁建模裁剪工作。
# 0.008229 1.7e-05
# 0.008411 1e-06
# 已完成俯仰角 40 度, 方位角 190 度的电磁建模裁剪工作。
# 0.001985 1.3e-05
# 0.006409 2e-06
# 已完成俯仰角 40 度, 方位角 200 度的电磁建模裁剪工作。
# 0.001964 2.1e-05
# 0.056747 2e-06
# 已完成俯仰角 40 度, 方位角 210 度的电磁建模裁剪工作。
# 0.001983 4.4e-05
# 0.000595 1e-06
# 已完成俯仰角 40 度, 方位角 220 度的电磁建模裁剪工作。
# 0.035072 2.3e-05
# 0.000927 5e-06
# 已完成俯仰角 40 度, 方位角 230 度的电磁建模裁剪工作。
# 0.416351 6e-06
# 0.025685 1e-06
# 已完成俯仰角 40 度, 方位角 240 度的电磁建模裁剪工作。
# 0.672857 2.5e-05
# 0.19506 2e-06
# 已完成俯仰角 40 度, 方位角 250 度的电磁建模裁剪工作。
# 0.696819 4.5e-05
# 0.144109 5e-06
# 已完成俯仰角 40 度, 方位角 260 度的电磁建模裁剪工作。
# 0.267401 4.2e-05
# 0.15023 2e-06
# 已完成俯仰角 40 度, 方位角 270 度的电磁建模裁剪工作。
# 0.572398 4.6e-05
# 0.114896 1e-06
# 已完成俯仰角 40 度, 方位角 280 度的电磁建模裁剪工作。
# 0.659265 1.8e-05
# 0.109299 3e-06
# 已完成俯仰角 40 度, 方位角 290 度的电磁建模裁剪工作。
# 0.399216 4.8e-05
# 0.13417 3e-06
# 已完成俯仰角 40 度, 方位角 300 度的电磁建模裁剪工作。
# 0.33397 3e-05
# 0.13946 2e-06
# 已完成俯仰角 40 度, 方位角 310 度的电磁建模裁剪工作。
# 0.41137 4.8e-05
# 0.134992 1e-06
# 已完成俯仰角 40 度, 方位角 320 度的电磁建模裁剪工作。
# 0.174576 2e-05
# 0.11246 1e-06
# 已完成俯仰角 40 度, 方位角 330 度的电磁建模裁剪工作。
# 0.048872 3.5e-05
# 0.013896 1e-06
# 已完成俯仰角 40 度, 方位角 340 度的电磁建模裁剪工作。
# 0.104424 8e-06
# 0.069508 1e-06
# 已完成俯仰角 40 度, 方位角 350 度的电磁建模裁剪工作。
# 0.002068 5.7e-05
# 0.1327 2e-06
# 已完成俯仰角 40 度, 方位角 360 度的电磁建模裁剪工作。
# 0.684676 3.7e-05
# 0.14806 2e-06
# 已完成俯仰角 45 度, 方位角 0 度的电磁建模裁剪工作。
# 0.45656 1.9e-05
# 0.157696 1e-06
# 已完成俯仰角 45 度, 方位角 10 度的电磁建模裁剪工作。
# 0.015868 4.3e-05
# 0.109047 1e-06
# 已完成俯仰角 45 度, 方位角 20 度的电磁建模裁剪工作。
# 0.090703 7e-06
# 0.111953 1e-06
# 已完成俯仰角 45 度, 方位角 30 度的电磁建模裁剪工作。
# 0.606412 2.1e-05
# 0.077816 1e-06
# 已完成俯仰角 45 度, 方位角 40 度的电磁建模裁剪工作。
# 0.697999 2.8e-05
# 0.135151 1e-06
# 已完成俯仰角 45 度, 方位角 50 度的电磁建模裁剪工作。
# 0.424992 4e-05
# 0.075227 5e-06
# 已完成俯仰角 45 度, 方位角 60 度的电磁建模裁剪工作。
# 0.369436 2.8e-05
# 0.181747 1e-06
# 已完成俯仰角 45 度, 方位角 70 度的电磁建模裁剪工作。
# 0.362101 2.1e-05
# 0.14072 6e-06
# 已完成俯仰角 45 度, 方位角 80 度的电磁建模裁剪工作。
# 0.202867 2.2e-05
# 0.150212 4e-06
# 已完成俯仰角 45 度, 方位角 90 度的电磁建模裁剪工作。
# 0.405682 8.8e-05
# 0.141786 1e-06
# 已完成俯仰角 45 度, 方位角 100 度的电磁建模裁剪工作。
# 0.455212 2.9e-05
# 0.205612 2e-06
# 已完成俯仰角 45 度, 方位角 110 度的电磁建模裁剪工作。
# 0.391662 2.4e-05
# 0.097015 2e-06
# 已完成俯仰角 45 度, 方位角 120 度的电磁建模裁剪工作。
# 0.001979 8e-06
# 0.000593 1e-06
# 已完成俯仰角 45 度, 方位角 130 度的电磁建模裁剪工作。
# 0.001961 2.7e-05
# 0.004169 1e-06
# 已完成俯仰角 45 度, 方位角 140 度的电磁建模裁剪工作。
# 0.001945 5e-05
# 0.123493 4e-06
# 已完成俯仰角 45 度, 方位角 150 度的电磁建模裁剪工作。
# 0.001941 1.9e-05
# 0.005305 1e-06
# 已完成俯仰角 45 度, 方位角 160 度的电磁建模裁剪工作。
# 0.642943 2.4e-05
# 0.163468 1e-06
# 已完成俯仰角 45 度, 方位角 170 度的电磁建模裁剪工作。
# 0.002008 1.7e-05
# 0.148123 1e-06
# 已完成俯仰角 45 度, 方位角 180 度的电磁建模裁剪工作。
# 0.672853 2.5e-05
# 0.007391 1e-06
# 已完成俯仰角 45 度, 方位角 190 度的电磁建模裁剪工作。
# 0.002267 3.3e-05
# 0.005305 2e-06
# 已完成俯仰角 45 度, 方位角 200 度的电磁建模裁剪工作。
# 0.001934 3.1e-05
# 0.123496 3e-06
# 已完成俯仰角 45 度, 方位角 210 度的电磁建模裁剪工作。
# 0.001957 1.5e-05
# 0.004165 1e-06
# 已完成俯仰角 45 度, 方位角 220 度的电磁建模裁剪工作。
# 0.001979 1.3e-05
# 0.000593 1e-06
# 已完成俯仰角 45 度, 方位角 230 度的电磁建模裁剪工作。
# 0.391673 4.5e-05
# 0.02573 2e-06
# 已完成俯仰角 45 度, 方位角 240 度的电磁建模裁剪工作。
# 0.4552 3.2e-05
# 0.204485 2e-06
# 已完成俯仰角 45 度, 方位角 250 度的电磁建模裁剪工作。
# 0.296729 5.2e-05
# 0.141786 1e-06
# 已完成俯仰角 45 度, 方位角 260 度的电磁建模裁剪工作。
# 0.39927 7e-05
# 0.150212 4e-06
# 已完成俯仰角 45 度, 方位角 270 度的电磁建模裁剪工作。
# 0.349949 3.5e-05
# 0.142772 6e-06
# 已完成俯仰角 45 度, 方位角 280 度的电磁建模裁剪工作。
# 0.369425 2.8e-05
# 0.18175 1e-06
# 已完成俯仰角 45 度, 方位角 290 度的电磁建模裁剪工作。
# 0.677685 4e-05
# 0.075203 5e-06
# 已完成俯仰角 45 度, 方位角 300 度的电磁建模裁剪工作。
# 0.69801 2.8e-05
# 0.135151 1e-06
# 已完成俯仰角 45 度, 方位角 310 度的电磁建模裁剪工作。
# 0.606384 3.7e-05
# 0.129044 4e-06
# 已完成俯仰角 45 度, 方位角 320 度的电磁建模裁剪工作。
# 0.059545 1.5e-05
# 0.111952 1e-06
# 已完成俯仰角 45 度, 方位角 330 度的电磁建模裁剪工作。
# 0.015867 2.4e-05
# 0.010198 1e-06
# 已完成俯仰角 45 度, 方位角 340 度的电磁建模裁剪工作。
# 0.674178 2.2e-05
# 0.063309 1e-06
# 已完成俯仰角 45 度, 方位角 350 度的电磁建模裁剪工作。
# 0.684676 3.7e-05
# 0.14806 2e-06
# 已完成俯仰角 45 度, 方位角 360 度的电磁建模裁剪工作。
# 0.013224 1.6e-05
# 0.147762 2e-06
# 已完成俯仰角 50 度, 方位角 0 度的电磁建模裁剪工作。
# 0.012078 1.5e-05
# 0.053931 2e-06
# 已完成俯仰角 50 度, 方位角 10 度的电磁建模裁剪工作。
# 0.003792 1.3e-05
# 0.180541 1e-06
# 已完成俯仰角 50 度, 方位角 20 度的电磁建模裁剪工作。
# 0.654485 4.7e-05
# 0.111256 2e-06
# 已完成俯仰角 50 度, 方位角 30 度的电磁建模裁剪工作。
# 0.603699 4.7e-05
# 0.121064 1e-06
# 已完成俯仰角 50 度, 方位角 40 度的电磁建模裁剪工作。
# 0.218694 1.7e-05
# 0.093118 1e-06
# 已完成俯仰角 50 度, 方位角 50 度的电磁建模裁剪工作。
# 0.430319 1.7e-05
# 0.17012 2e-06
# 已完成俯仰角 50 度, 方位角 60 度的电磁建模裁剪工作。
# 0.504509 3e-05
# 0.105486 2e-06
# 已完成俯仰角 50 度, 方位角 70 度的电磁建模裁剪工作。
# 0.454061 2.6e-05
# 0.114701 2e-06
# 已完成俯仰角 50 度, 方位角 80 度的电磁建模裁剪工作。
# 0.506378 6.9e-05
# 0.188321 8e-06
# 已完成俯仰角 50 度, 方位角 90 度的电磁建模裁剪工作。
# 0.279636 4.6e-05
# 0.11194 8e-06
# 已完成俯仰角 50 度, 方位角 100 度的电磁建模裁剪工作。
# 0.520674 6e-06
# 0.194398 1e-06
# 已完成俯仰角 50 度, 方位角 110 度的电磁建模裁剪工作。
# 0.563816 6.8e-05
# 0.025762 5e-06
# 已完成俯仰角 50 度, 方位角 120 度的电磁建模裁剪工作。
# 0.001989 1.8e-05
# 0.00059 3e-06
# 已完成俯仰角 50 度, 方位角 130 度的电磁建模裁剪工作。
# 0.002024 1e-06
# 0.001771 1e-06
# 已完成俯仰角 50 度, 方位角 140 度的电磁建模裁剪工作。
# 0.00194 2e-05
# 0.12239 1e-06
# 已完成俯仰角 50 度, 方位角 150 度的电磁建模裁剪工作。
# 0.001983 8e-06
# 0.004314 2e-06
# 已完成俯仰角 50 度, 方位角 160 度的电磁建模裁剪工作。
# 0.011869 2.4e-05
# 0.091808 4e-06
# 已完成俯仰角 50 度, 方位角 170 度的电磁建模裁剪工作。
# 0.001974 1.2e-05
# 0.147819 2e-06
# 已完成俯仰角 50 度, 方位角 180 度的电磁建模裁剪工作。
# 0.011162 2e-05
# 0.091808 4e-06
# 已完成俯仰角 50 度, 方位角 190 度的电磁建模裁剪工作。
# 0.001923 1.8e-05
# 0.004314 2e-06
# 已完成俯仰角 50 度, 方位角 200 度的电磁建模裁剪工作。
# 0.00189 2.2e-05
# 0.121518 3e-06
# 已完成俯仰角 50 度, 方位角 210 度的电磁建模裁剪工作。
# 0.001927 1.5e-05
# 0.000573 1e-06
# 已完成俯仰角 50 度, 方位角 220 度的电磁建模裁剪工作。
# 0.001986 2.6e-05
# 0.00059 1e-06
# 已完成俯仰角 50 度, 方位角 230 度的电磁建模裁剪工作。
# 0.578408 5.2e-05
# 0.08076 1.6e-05
# 已完成俯仰角 50 度, 方位角 240 度的电磁建模裁剪工作。
# 0.520676 5.7e-05
# 0.196517 2e-06
# 已完成俯仰角 50 度, 方位角 250 度的电磁建模裁剪工作。
# 0.420195 6.7e-05
# 0.185375 8e-06
# 已完成俯仰角 50 度, 方位角 260 度的电磁建模裁剪工作。
# 0.506349 6.9e-05
# 0.204451 8e-06
# 已完成俯仰角 50 度, 方位角 270 度的电磁建模裁剪工作。
# 0.453878 2.6e-05
# 0.059562 2e-06
# 已完成俯仰角 50 度, 方位角 280 度的电磁建模裁剪工作。
# 0.504534 6.1e-05
# 0.129372 2e-06
# 已完成俯仰角 50 度, 方位角 290 度的电磁建模裁剪工作。
# 0.430287 4.6e-05
# 0.170119 3e-06
# 已完成俯仰角 50 度, 方位角 300 度的电磁建模裁剪工作。
# 0.487191 1.7e-05
# 0.129266 1e-06
# 已完成俯仰角 50 度, 方位角 310 度的电磁建模裁剪工作。
# 0.60367 4e-05
# 0.07782 1e-06
# 已完成俯仰角 50 度, 方位角 320 度的电磁建模裁剪工作。
# 0.654483 4.7e-05
# 0.111255 2e-06
# 已完成俯仰角 50 度, 方位角 330 度的电磁建模裁剪工作。
# 0.003792 1.9e-05
# 0.181281 1e-06
# 已完成俯仰角 50 度, 方位角 340 度的电磁建模裁剪工作。
# 0.012078 3.3e-05
# 0.055667 2e-06
# 已完成俯仰角 50 度, 方位角 350 度的电磁建模裁剪工作。
# 0.013224 1.6e-05
# 0.147762 2e-06
# 已完成俯仰角 50 度, 方位角 360 度的电磁建模裁剪工作。
# 0.696994 3.4e-05
# 0.148772 2e-06
# 已完成俯仰角 55 度, 方位角 0 度的电磁建模裁剪工作。
# 0.041894 1.7e-05
# 0.044484 1e-06
# 已完成俯仰角 55 度, 方位角 10 度的电磁建模裁剪工作。
# 0.165586 3.7e-05
# 0.041273 1e-06
# 已完成俯仰角 55 度, 方位角 20 度的电磁建模裁剪工作。
# 0.686373 3.9e-05
# 0.11027 1e-06
# 已完成俯仰角 55 度, 方位角 30 度的电磁建模裁剪工作。
# 0.660254 2e-06
# 0.041092 1e-06
# 已完成俯仰角 55 度, 方位角 40 度的电磁建模裁剪工作。
# 0.573534 3.8e-05
# 0.121052 2e-06
# 已完成俯仰角 55 度, 方位角 50 度的电磁建模裁剪工作。
# 0.196863 2.2e-05
# 0.108254 1e-06
# 已完成俯仰角 55 度, 方位角 60 度的电磁建模裁剪工作。
# 0.231512 2.6e-05
# 0.140486 3e-06
# 已完成俯仰角 55 度, 方位角 70 度的电磁建模裁剪工作。
# 0.276882 3.4e-05
# 0.177231 1e-06
# 已完成俯仰角 55 度, 方位角 80 度的电磁建模裁剪工作。
# 0.211978 2.9e-05
# 0.209426 1e-06
# 已完成俯仰角 55 度, 方位角 90 度的电磁建模裁剪工作。
# 0.619287 3e-05
# 0.065625 3e-06
# 已完成俯仰角 55 度, 方位角 100 度的电磁建模裁剪工作。
# 0.308448 5.8e-05
# 0.188055 1e-06
# 已完成俯仰角 55 度, 方位角 110 度的电磁建模裁剪工作。
# 0.002967 4e-06
# 0.061651 1e-06
# 已完成俯仰角 55 度, 方位角 120 度的电磁建模裁剪工作。
# 0.001969 4.3e-05
# 0.000582 1e-06
# 已完成俯仰角 55 度, 方位角 130 度的电磁建模裁剪工作。
# 0.005941 2e-05
# 0.000667 1e-06
# 已完成俯仰角 55 度, 方位角 140 度的电磁建模裁剪工作。
# 0.001944 5e-06
# 0.121604 2e-06
# 已完成俯仰角 55 度, 方位角 150 度的电磁建模裁剪工作。
# 0.001956 1.7e-05
# 0.003259 3e-06
# 已完成俯仰角 55 度, 方位角 160 度的电磁建模裁剪工作。
# 0.001986 9e-06
# 0.049484 2e-06
# 已完成俯仰角 55 度, 方位角 170 度的电磁建模裁剪工作。
# 0.001967 2e-05
# 0.150172 2e-06
# 已完成俯仰角 55 度, 方位角 180 度的电磁建模裁剪工作。
# 0.001987 5.3e-05
# 0.036568 2e-06
# 已完成俯仰角 55 度, 方位角 190 度的电磁建模裁剪工作。
# 0.001876 1.4e-05
# 0.003259 3e-06
# 已完成俯仰角 55 度, 方位角 200 度的电磁建模裁剪工作。
# 0.001831 2e-05
# 0.121263 2e-06
# 已完成俯仰角 55 度, 方位角 210 度的电磁建模裁剪工作。
# 0.001911 7.8e-05
# 0.000564 1e-06
# 已完成俯仰角 55 度, 方位角 220 度的电磁建模裁剪工作。
# 0.001968 3.1e-05
# 0.000582 1e-06
# 已完成俯仰角 55 度, 方位角 230 度的电磁建模裁剪工作。
# 0.002967 6e-06
# 0.061634 1e-06
# 已完成俯仰角 55 度, 方位角 240 度的电磁建模裁剪工作。
# 0.23052 5.8e-05
# 0.188069 1e-06
# 已完成俯仰角 55 度, 方位角 250 度的电磁建模裁剪工作。
# 0.619296 1.1e-05
# 0.133967 3e-06
# 已完成俯仰角 55 度, 方位角 260 度的电磁建模裁剪工作。
# 0.211978 2.9e-05
# 0.209424 1e-06
# 已完成俯仰角 55 度, 方位角 270 度的电磁建模裁剪工作。
# 0.276893 3.3e-05
# 0.179627 2e-06
# 已完成俯仰角 55 度, 方位角 280 度的电磁建模裁剪工作。
# 0.231512 1.4e-05
# 0.134835 3e-06
# 已完成俯仰角 55 度, 方位角 290 度的电磁建模裁剪工作。
# 0.14055 2.8e-05
# 0.108235 1e-06
# 已完成俯仰角 55 度, 方位角 300 度的电磁建模裁剪工作。
# 0.677089 2.1e-05
# 0.121058 2e-06
# 已完成俯仰角 55 度, 方位角 310 度的电磁建模裁剪工作。
# 0.229876 1.6e-05
# 0.110178 1e-06
# 已完成俯仰角 55 度, 方位角 320 度的电磁建模裁剪工作。
# 0.689577 1.1e-05
# 0.110269 1e-06
# 已完成俯仰角 55 度, 方位角 330 度的电磁建模裁剪工作。
# 0.165592 2.3e-05
# 0.041273 1e-06
# 已完成俯仰角 55 度, 方位角 340 度的电磁建模裁剪工作。
# 0.022972 1.2e-05
# 0.046375 1e-06
# 已完成俯仰角 55 度, 方位角 350 度的电磁建模裁剪工作。
# 0.696994 3.4e-05
# 0.148772 2e-06
# 已完成俯仰角 55 度, 方位角 360 度的电磁建模裁剪工作。

# %% [markdown]
# 步骤4：进行回波仿真

# %%
if os.path.exists(save_echo_folder_name):
    shutil.rmtree(save_echo_folder_name)
mk_save_echo_floder = 'mkdir echo'
result = subprocess.run(mk_save_echo_floder, shell=True, capture_output=True, text=True, cwd=main_folder, check=True)

for k in range(20,56,5):
    for i in range(0,37,1):
        for j in range(1):
            main_degree = 10*i
            modelingResultPath = save_mat_folder_name + 'mat_' + str(k) + '_' + str(main_degree) + '_' + str(j) + '.mat'
            echoResultPath = save_echo_folder_name + 'echo_' + str(k) + '_' + str(main_degree) + '_' + str(j) + '.mat'
            settingsPath = main_folder + '/settings.mat'        # 中间参数文件结果

            # modelingResultPath = "/home/chenjc/newprojects/scripts/HBFZ/EchoSimProd/ALBK.mat"
            # #modelingResultPath = "/home/chenjc/newprojects/scripts/HBFZ/EchoSim/4pt.mat"
            # echoResultPath = "/home/chenjc/newprojects/scripts/HBFZ/EchoSimProd/test.mat"
            # settingsPath = "/home/chenjc/newprojects/scripts/HBFZ/EchoSimProd/settings.mat"        # 中间参数文件结果

            

            workMode = 1        # 工作体制（单通道）
            simSatMode = 1      # 卫星解算方式（自定义）
            echoMethod = 1      # 回波生成方式（快速fft）
            initParams = {"scanMode": scanMode,\
                        "workMode": workMode,\
                        "rngRho": rngRho,\
                        "azmRho": azmRho,\
                        "simSatMode": simSatMode,\
                        "echoMethod": echoMethod}
            

            # 其他参数
            squiAng = 0        # 斜视情况所需参数
            threadNum = 48     # CPU并行线程数
            sightRange = 3e3   # 卫星与场景的最短距离，自定义和实际轨道均有效，此时仿真轨道非实际轨道
            targetV = np.array([0, 0, 0], dtype="double").reshape(-1,1)       # 将速度矢量转化为np列向量

            # 误差参数
            echoWinStartEdge = 0;       # 回波窗起始沿误差 ns级, 正值对应信号前移
            sysDelay = 0;               # 系统延时测量误差        正值对应信号右移
            innoPhaseErr = 0;            # 电离层主要引起相位误差  弧度
            tropPhaseErr = 0;            # 对流层主要引起时延以及幅度下降
            tropAmpDec = 1;              # 幅度下降因子

            addonParams = {
                "squiAng": squiAng,
                "threadNum": threadNum,
                "sightRange": sightRange,
                "targetV": targetV,
                "echoWinStartEdge": echoWinStartEdge,
                "sysDelay": sysDelay,
                "innoPhaseErr": innoPhaseErr,
                "tropPhaseErr": tropPhaseErr,
                "tropAmpDec": tropAmpDec
            }
            initParams.update(addonParams)

            # 根据不同模式设置天线长度
            if scanMode == 1:
                La = 2*azmRho
            elif scanMode == 2:
                La = 3
            elif scanMode == 3:
                La = 4
            elif scanMode == 4:
                La = 4
            elif scanMode == 5:
                La = 4
            elif scanMode == 6:
                La = 2*azmRho

            # 距离扫描所需参数
            subStripNum = 2
            subStripRng = 25e3
            # 多通道时所需参数
            channelNum = 8

            extra = {"La": La, "subStripNum": subStripNum, "subStripRng": subStripRng,\
                    "channelNum": channelNum}

            # 轨道参数设置
            orbital = {"majAxis": 6893.38359077456e3,\
                    "eccRatio": 0.0013485366190770,\
                    "incAng": 97.4477903825153,\
                    "ascdLng": 295.304778902499,\
                    "perigee": 66.7207893275409}

            # 场景约束
            scn = {"tgLat": 28.06194738,\
                "tgLng": 112.89267163,\
                "tgHeight": 54.8}

            # 雷达参数
            radar = {"c": 3e8, "fc": 9.6e9, "Tp": 5e-6, "riseRatio": 16}

            initParams.update(extra)
            initParams.update(orbital)
            initParams.update(scn)
            initParams.update(radar)

            # 这一步一旦散射矩阵被当做整数解析就会出问题！
            modelResult = sio.loadmat(modelingResultPath)
            modelResult["data"] = np.array(modelResult["data"], dtype="double")
            initParams.update(modelResult)

            # 保存参数
            sio.savemat(settingsPath, initParams)

            echoSimPath = "/home/chenjc/newprojects/scripts/HBFZ/EchoSimProd/build"
            # 运行回波程序
            try:
                print("开始回波仿真...")
                echoSimCmd = ["./main", settingsPath, echoResultPath]
                result = subprocess.run(echoSimCmd, capture_output=False, text=True, check=True, cwd=echoSimPath)       # 屏蔽输出避免跨平台开发导致的编码问题
                print(result.stdout)
            except Exception as e:
                print(e)
                print("回波仿真异常！")
                raise
            else:
                print("回波仿真完成！")
# Out:
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.246s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.066s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.404s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.887s
#   Final -- Total Cost: 27.606s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.211s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.054s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.99s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.756s
#   Final -- Total Cost: 27.013s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.23s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.051s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.934s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.971s
#   Final -- Total Cost: 27.188s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.247s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.673s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 2.299s
#   Final -- Total Cost: 28.274s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.198s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.049s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.24s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.793s
#   Final -- Total Cost: 27.282s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.212s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.05s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.039s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.89s
#   Final -- Total Cost: 27.192s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.215s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.053s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.673s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.657s
#   Final -- Total Cost: 27.599s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.207s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.05s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 26.154s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.872s
#   Final -- Total Cost: 28.285s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.203s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.047s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.51s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.804s
#   Final -- Total Cost: 27.566s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.208s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.049s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.057s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.841s
#   Final -- Total Cost: 27.156s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.159s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.047s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.115s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.911s
#   Final -- Total Cost: 27.234s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.255s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.074s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.772s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.838s
#   Final -- Total Cost: 26.941s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.244s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.796s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.937s
#   Final -- Total Cost: 28.029s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.246s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.064s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.777s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.895s
#   Final -- Total Cost: 26.985s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.225s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.832s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.86s
#   Final -- Total Cost: 26.97s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.213s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.914s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.863s
#   Final -- Total Cost: 27.044s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.212s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.128s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.725s
#   Final -- Total Cost: 27.12s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.216s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.453s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.852s
#   Final -- Total Cost: 27.575s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.245s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.574s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.796s
#   Final -- Total Cost: 27.669s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.178s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.065s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.011s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.989s
#   Final -- Total Cost: 27.245s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.218s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.203s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.891s
#   Final -- Total Cost: 27.366s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.239s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.049s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.377s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.935s
#   Final -- Total Cost: 27.602s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.217s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.053s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.931s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.855s
#   Final -- Total Cost: 27.059s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.212s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.051s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.225s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.907s
#   Final -- Total Cost: 27.397s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.24s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.992s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.826s
#   Final -- Total Cost: 27.112s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.228s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.413s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.789s
#   Final -- Total Cost: 27.484s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.219s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.05s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.018s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.953s
#   Final -- Total Cost: 27.242s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.242s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.053s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.079s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.912s
#   Final -- Total Cost: 27.287s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.242s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.053s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.508s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.804s
#   Final -- Total Cost: 27.608s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.213s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.168s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 2.087s
#   Final -- Total Cost: 27.522s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.211s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.049s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.321s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.917s
#   Final -- Total Cost: 27.5s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.248s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.145s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.817s
#   Final -- Total Cost: 27.264s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.177s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.08s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.275s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.913s
#   Final -- Total Cost: 27.447s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.219s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.094s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.171s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.865s
#   Final -- Total Cost: 27.351s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.208s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.533s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.796s
#   Final -- Total Cost: 26.591s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.21s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.051s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.595s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.975s
#   Final -- Total Cost: 27.834s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.251s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.059s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.981s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.882s
#   Final -- Total Cost: 27.174s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.249s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.086s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.531s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.583s
#   Final -- Total Cost: 26.451s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.211s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.051s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.56s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.682s
#   Final -- Total Cost: 26.505s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.244s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.085s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.861s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.681s
#   Final -- Total Cost: 26.874s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.243s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.086s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.848s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.663s
#   Final -- Total Cost: 26.849s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.247s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.074s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.169s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.65s
#   Final -- Total Cost: 26.142s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.24s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.053s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.141s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.604s
#   Final -- Total Cost: 26.039s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.201s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.05s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.945s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.747s
#   Final -- Total Cost: 26.944s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.211s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.058s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.324s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.67s
#   Final -- Total Cost: 27.265s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.203s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.051s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.626s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.698s
#   Final -- Total Cost: 26.58s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.207s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.202s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.651s
#   Final -- Total Cost: 27.114s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.241s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.064s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.702s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.669s
#   Final -- Total Cost: 26.678s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.209s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.053s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.503s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.657s
#   Final -- Total Cost: 27.425s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.212s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.053s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.087s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.685s
#   Final -- Total Cost: 27.038s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.2s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.048s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.347s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.797s
#   Final -- Total Cost: 27.393s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.212s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.117s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.646s
#   Final -- Total Cost: 27.029s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.229s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.364s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.627s
#   Final -- Total Cost: 26.275s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.208s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.051s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.402s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.705s
#   Final -- Total Cost: 26.367s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.204s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.654s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.651s
#   Final -- Total Cost: 25.564s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.207s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.827s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.745s
#   Final -- Total Cost: 26.832s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.221s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.056s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.952s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.739s
#   Final -- Total Cost: 26.97s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.212s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.488s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.525s
#   Final -- Total Cost: 26.279s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.208s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.98s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.67s
#   Final -- Total Cost: 25.911s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.204s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.049s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.792s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.678s
#   Final -- Total Cost: 26.725s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.234s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.058s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.229s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.631s
#   Final -- Total Cost: 27.154s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.21s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.931s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.66s
#   Final -- Total Cost: 25.856s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.237s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.053s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.446s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.643s
#   Final -- Total Cost: 27.381s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.249s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.085s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.072s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.94s
#   Final -- Total Cost: 27.348s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.206s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.048s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.228s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.566s
#   Final -- Total Cost: 26.05s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.226s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.087s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.888s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.674s
#   Final -- Total Cost: 26.877s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.208s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.049s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.838s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.491s
#   Final -- Total Cost: 26.587s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.202s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.048s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.659s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.609s
#   Final -- Total Cost: 26.52s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.206s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.047s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.831s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.654s
#   Final -- Total Cost: 26.741s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.202s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.058s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.938s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.619s
#   Final -- Total Cost: 26.819s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.24s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.076s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.297s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.733s
#   Final -- Total Cost: 26.348s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.229s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.051s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.294s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.554s
#   Final -- Total Cost: 26.13s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.202s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.049s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 25.604s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.678s
#   Final -- Total Cost: 27.536s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.202s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.571s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.701s
#   Final -- Total Cost: 26.529s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.206s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.389s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.632s
#   Final -- Total Cost: 25.281s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.229s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.062s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.766s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.544s
#   Final -- Total Cost: 25.603s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.203s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.051s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.658s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.536s
#   Final -- Total Cost: 25.45s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.205s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.05s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.573s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.549s
#   Final -- Total Cost: 26.379s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.204s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.05s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.918s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.53s
#   Final -- Total Cost: 25.703s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.201s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.663s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.543s
#   Final -- Total Cost: 25.46s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.24s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.086s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.347s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.533s
#   Final -- Total Cost: 25.208s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.205s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.262s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.61s
#   Final -- Total Cost: 26.131s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.212s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.052s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.006s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.476s
#   Final -- Total Cost: 25.748s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.199s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.05s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.704s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.484s
#   Final -- Total Cost: 25.438s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.201s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.051s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.875s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.564s
#   Final -- Total Cost: 25.693s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.241s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.058s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.716s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.513s
#   Final -- Total Cost: 25.529s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.205s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.053s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.43s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.539s
#   Final -- Total Cost: 25.228s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.209s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.056s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 24.06s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.602s
#   Final -- Total Cost: 25.929s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.238s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.065s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 23.651s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.578s
#   Final -- Total Cost: 25.535s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.199s
# ...
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.027s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.221s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.218s
#   Final -- Total Cost: 16.641s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.169s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.026s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.421s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.298s
#   Final -- Total Cost: 16.916s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.188s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.041s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.119s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.285s
#   Final -- Total Cost: 16.635s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.172s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.027s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.575s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.648s
#   Final -- Total Cost: 17.423s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.191s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.043s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.194s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.218s
#   Final -- Total Cost: 16.648s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.168s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.026s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.144s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.28s
#   Final -- Total Cost: 16.621s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.145s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.026s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.561s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.256s
#   Final -- Total Cost: 15.991s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.166s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.025s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.072s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.339s
#   Final -- Total Cost: 16.604s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.167s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.026s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.844s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.372s
#   Final -- Total Cost: 16.411s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.164s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.026s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.75s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.228s
#   Final -- Total Cost: 16.17s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.165s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.025s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.698s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.27s
#   Final -- Total Cost: 16.16s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.138s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.026s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.593s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.297s
#   Final -- Total Cost: 16.057s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.165s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.026s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.643s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.285s
#   Final -- Total Cost: 16.121s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.188s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.043s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.354s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.258s
#   Final -- Total Cost: 16.846s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.164s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.025s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.569s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.273s
#   Final -- Total Cost: 16.033s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.167s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.03s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.613s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.137s
#   Final -- Total Cost: 15.949s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.135s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.024s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.143s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.271s
#   Final -- Total Cost: 16.575s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.19s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.044s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.132s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.266s
#   Final -- Total Cost: 16.633s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.153s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.027s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.314s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.289s
#   Final -- Total Cost: 16.784s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.168s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.025s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.995s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.278s
#   Final -- Total Cost: 16.468s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.189s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.041s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.504s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.155s
#   Final -- Total Cost: 16.89s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.166s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.024s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.664s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.262s
#   Final -- Total Cost: 17.118s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.168s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.026s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.299s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.225s
#   Final -- Total Cost: 16.72s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.167s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.025s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.958s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.362s
#   Final -- Total Cost: 16.513s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.167s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.026s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.303s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.213s
#   Final -- Total Cost: 16.711s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.188s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.043s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.978s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.297s
#   Final -- Total Cost: 16.509s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.165s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.027s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.067s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.247s
#   Final -- Total Cost: 16.507s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.174s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.027s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 15.395s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.238s
#   Final -- Total Cost: 16.837s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.183s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.038s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.822s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.206s
#   Final -- Total Cost: 16.251s
# None
# 回波仿真完成！
# 开始回波仿真...
# ========================= EchoSimProcess =========================
# Phase 1 -- Params read and config...
# Phase 1 -- Done! Cost: 0.167s
# Phase 2 -- Sat Position Calculate...
# Phase 2 -- Done! Cost: 0s
# Phase 3 -- Flight Track and BeamDir History Simulate...
# Phase 3 -- Done! Cost: 0s
# Phase 4 -- Signal Generate...
# Phase 4 -- Done! Cost: 0.034s
# Phase 5 -- Echo Calculate...
#         -- CPU ThreadNum: 48
# Phase 5 -- Done! Cost: 14.64s
# Phase 6 -- Result Save...
# Phase 6 -- Done! Cost: 1.345s
#   Final -- Total Cost: 16.188s
# None
# 回波仿真完成！

# %% [markdown]
# 步骤5：进行成像处理

# %%
if os.path.exists(save_img_folder_name):
    shutil.rmtree(save_img_folder_name)
mk_save_img_floder = 'mkdir img'
result = subprocess.run(mk_save_img_floder, shell=True, capture_output=True, text=True, cwd=main_folder, check=True)

for k in range(20,56,5):
    for i in range(0,37,1):
        for j in range(1):
            main_degree = 10*i
            data_path = save_echo_folder_name + 'echo_' + str(k) + '_' + str(main_degree) + '_' + str(j) + '.mat'
            save_path = save_img_folder_name + 'img_' + str(k) + '_' + str(main_degree) + '_' + str(j) + '.mat'
            imaging_current = imaging(data_path, beta)
            imaging_current.imaging()
            imaging_current.show_image(2, save_path,model_name)
        print('已完成俯仰角 {} 度, 方位角 {} 度的回波成像工作。'.format(k, 10*i))
# Out:
# 已完成俯仰角 20 度, 方位角 0 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 10 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 20 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 30 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 40 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 50 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 60 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 70 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 80 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 90 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 100 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 110 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 120 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 130 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 140 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 150 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 160 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 170 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 180 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 190 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 200 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 210 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 220 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 230 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 240 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 250 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 260 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 270 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 280 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 290 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 300 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 310 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 320 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 330 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 340 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 350 度的回波成像工作。
# 已完成俯仰角 20 度, 方位角 360 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 0 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 10 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 20 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 30 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 40 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 50 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 60 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 70 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 80 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 90 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 100 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 110 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 120 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 130 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 140 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 150 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 160 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 170 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 180 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 190 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 200 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 210 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 220 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 230 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 240 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 250 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 260 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 270 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 280 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 290 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 300 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 310 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 320 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 330 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 340 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 350 度的回波成像工作。
# 已完成俯仰角 25 度, 方位角 360 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 0 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 10 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 20 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 30 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 40 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 50 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 60 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 70 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 80 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 90 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 100 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 110 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 120 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 130 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 140 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 150 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 160 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 170 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 180 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 190 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 200 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 210 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 220 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 230 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 240 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 250 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 260 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 270 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 280 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 290 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 300 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 310 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 320 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 330 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 340 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 350 度的回波成像工作。
# 已完成俯仰角 30 度, 方位角 360 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 0 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 10 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 20 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 30 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 40 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 50 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 60 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 70 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 80 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 90 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 100 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 110 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 120 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 130 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 140 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 150 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 160 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 170 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 180 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 190 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 200 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 210 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 220 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 230 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 240 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 250 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 260 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 270 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 280 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 290 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 300 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 310 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 320 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 330 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 340 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 350 度的回波成像工作。
# 已完成俯仰角 35 度, 方位角 360 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 0 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 10 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 20 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 30 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 40 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 50 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 60 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 70 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 80 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 90 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 100 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 110 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 120 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 130 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 140 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 150 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 160 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 170 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 180 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 190 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 200 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 210 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 220 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 230 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 240 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 250 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 260 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 270 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 280 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 290 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 300 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 310 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 320 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 330 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 340 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 350 度的回波成像工作。
# 已完成俯仰角 40 度, 方位角 360 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 0 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 10 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 20 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 30 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 40 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 50 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 60 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 70 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 80 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 90 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 100 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 110 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 120 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 130 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 140 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 150 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 160 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 170 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 180 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 190 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 200 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 210 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 220 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 230 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 240 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 250 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 260 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 270 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 280 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 290 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 300 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 310 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 320 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 330 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 340 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 350 度的回波成像工作。
# 已完成俯仰角 45 度, 方位角 360 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 0 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 10 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 20 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 30 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 40 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 50 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 60 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 70 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 80 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 90 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 100 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 110 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 120 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 130 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 140 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 150 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 160 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 170 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 180 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 190 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 200 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 210 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 220 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 230 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 240 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 250 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 260 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 270 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 280 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 290 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 300 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 310 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 320 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 330 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 340 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 350 度的回波成像工作。
# 已完成俯仰角 50 度, 方位角 360 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 0 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 10 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 20 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 30 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 40 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 50 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 60 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 70 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 80 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 90 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 100 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 110 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 120 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 130 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 140 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 150 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 160 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 170 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 180 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 190 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 200 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 210 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 220 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 230 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 240 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 250 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 260 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 270 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 280 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 290 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 300 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 310 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 320 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 330 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 340 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 350 度的回波成像工作。
# 已完成俯仰角 55 度, 方位角 360 度的回波成像工作。

# %% [markdown]
# 步骤6：将成像结果存为.png文件

# %%
if os.path.exists(save_png_folder_name):
    shutil.rmtree(save_png_folder_name)
mk_save_png_floder = 'mkdir png'
result = subprocess.run(mk_save_png_floder, shell=True, capture_output=True, text=True, cwd=main_folder, check=True)

for k in range(20,56,5):
  for i in range(0,37,1):
    for j in range(1):
      main_degree = 10*i
      data_path = save_img_folder_name + 'img_' + str(k) + '_' + str(main_degree) + '_' + str(j) + '.mat'
      save_path = save_png_folder_name + 'png_' + str(k) + '_' + str(main_degree) + '_' + str(j) + '.png'
      image = sio.loadmat(data_path)['image']
      # # 裁剪
      # l = int(data.shape[1]/2 - data.shape[0]/2*0.8); r = int(data.shape[1]/2 + data.shape[0]/2*0.8)
      # u = int(data.shape[0]*0.1+1); d = int(data.shape[0]*0.9)
      # image = np.array(data[u:d,l:r], dtype=np.uint8)
      # image = np.array(data, dtype=np.uint8)
      mpimg.imsave(save_path, image, cmap=plt.cm.gray)
    print('已完成俯仰角 {} 度, 方位角 {} 度的成像结果储存。'.format(k, 10*i))
# Out:
# 已完成俯仰角 20 度, 方位角 0 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 10 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 20 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 30 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 40 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 50 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 60 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 70 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 80 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 90 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 100 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 110 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 120 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 130 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 140 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 150 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 160 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 170 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 180 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 190 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 200 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 210 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 220 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 230 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 240 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 250 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 260 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 270 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 280 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 290 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 300 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 310 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 320 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 330 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 340 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 350 度的成像结果储存。
# 已完成俯仰角 20 度, 方位角 360 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 0 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 10 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 20 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 30 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 40 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 50 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 60 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 70 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 80 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 90 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 100 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 110 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 120 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 130 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 140 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 150 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 160 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 170 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 180 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 190 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 200 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 210 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 220 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 230 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 240 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 250 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 260 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 270 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 280 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 290 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 300 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 310 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 320 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 330 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 340 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 350 度的成像结果储存。
# 已完成俯仰角 25 度, 方位角 360 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 0 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 10 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 20 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 30 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 40 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 50 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 60 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 70 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 80 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 90 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 100 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 110 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 120 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 130 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 140 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 150 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 160 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 170 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 180 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 190 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 200 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 210 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 220 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 230 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 240 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 250 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 260 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 270 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 280 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 290 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 300 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 310 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 320 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 330 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 340 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 350 度的成像结果储存。
# 已完成俯仰角 30 度, 方位角 360 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 0 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 10 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 20 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 30 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 40 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 50 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 60 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 70 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 80 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 90 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 100 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 110 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 120 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 130 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 140 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 150 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 160 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 170 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 180 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 190 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 200 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 210 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 220 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 230 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 240 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 250 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 260 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 270 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 280 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 290 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 300 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 310 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 320 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 330 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 340 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 350 度的成像结果储存。
# 已完成俯仰角 35 度, 方位角 360 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 0 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 10 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 20 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 30 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 40 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 50 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 60 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 70 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 80 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 90 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 100 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 110 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 120 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 130 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 140 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 150 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 160 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 170 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 180 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 190 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 200 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 210 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 220 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 230 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 240 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 250 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 260 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 270 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 280 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 290 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 300 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 310 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 320 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 330 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 340 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 350 度的成像结果储存。
# 已完成俯仰角 40 度, 方位角 360 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 0 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 10 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 20 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 30 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 40 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 50 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 60 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 70 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 80 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 90 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 100 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 110 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 120 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 130 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 140 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 150 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 160 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 170 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 180 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 190 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 200 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 210 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 220 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 230 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 240 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 250 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 260 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 270 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 280 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 290 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 300 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 310 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 320 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 330 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 340 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 350 度的成像结果储存。
# 已完成俯仰角 45 度, 方位角 360 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 0 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 10 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 20 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 30 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 40 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 50 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 60 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 70 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 80 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 90 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 100 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 110 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 120 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 130 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 140 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 150 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 160 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 170 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 180 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 190 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 200 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 210 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 220 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 230 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 240 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 250 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 260 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 270 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 280 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 290 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 300 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 310 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 320 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 330 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 340 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 350 度的成像结果储存。
# 已完成俯仰角 50 度, 方位角 360 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 0 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 10 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 20 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 30 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 40 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 50 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 60 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 70 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 80 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 90 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 100 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 110 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 120 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 130 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 140 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 150 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 160 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 170 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 180 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 190 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 200 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 210 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 220 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 230 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 240 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 250 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 260 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 270 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 280 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 290 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 300 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 310 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 320 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 330 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 340 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 350 度的成像结果储存。
# 已完成俯仰角 55 度, 方位角 360 度的成像结果储存。
